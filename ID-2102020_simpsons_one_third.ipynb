# %%
import numpy as np

def f(x):
    return x**2 + x - 2

a = 0
b = 1
n = 2
h = (b - a) / n

x0 = a
x1 =(a+b)/2
x2 = b

result = (h / 3) * (f(x0) + 4*f(x1) + f(x2))
print("Result =", result)
# Out:
# Integration result: 10.666666666666666
