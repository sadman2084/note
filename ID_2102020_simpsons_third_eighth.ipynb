# %%
import numpy as np

def f(x):
    return x**2 + x + 2

a=0
b=1
n=3
h=(b - a) / n
x0=a
x1=a + h
x2=a + 2*h
x3=b

result=(3*h/8)*(f(x0)+3*f(x1)+3*f(x2)+f(x3))
print(result)
# Out:
# Integration result: 10.666666666666666
